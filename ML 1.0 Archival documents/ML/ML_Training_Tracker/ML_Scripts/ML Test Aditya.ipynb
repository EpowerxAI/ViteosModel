# %%
import pandas as pd

# %%
data = pd.read_csv("temp_predict.csv")

# %%
data.head()
# Out:
#    Unnamed: 0      BreakID Status Currency Custodian Account          ISIN  \
# 0           0  267406512.0    SMR      GBP      ACI_OKR1_UMB  GB00B63QSB39
# 1           1  267406513.0    SMR      EUR      ACI_OKR1_UMB  ES0130625512
# 2           2  267406515.0    SMR      EUR      ACI_OKR1_UMB  NL0000387058
# 3           3  267406516.0    SMR      EUR      ACI_OKR1_UMB  DE0005419105
# 4           4  267406517.0    SMR      EUR      ACI_OKR1_UMB  IT0003073266
#
#   Transaction Type  Trade Date Settle Date  CUSIP  ...  \
# 0              Buy  11-16-2018  11-20-2018    NaN  ...
# 1             Sell  11-16-2018  11-20-2018    NaN  ...
# 2             Sell  11-16-2018  11-20-2018    NaN  ...
# 3             Sell  11-16-2018  11-20-2018    NaN  ...
# 4             Sell  11-16-2018  11-20-2018    NaN  ...
#
#   Trade Expenses Difference Absolute Accounting OTE Custodian Account  \
# 0                                0.0                              NaN
# ...

# %%
data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
data.head()
# Out:
#    Unnamed: 0      BreakID Status Currency Custodian Account          ISIN  \
# 0           0  267406512.0    SMR      GBP      ACI_OKR1_UMB  GB00B63QSB39
# 1           1  267406513.0    SMR      EUR      ACI_OKR1_UMB  ES0130625512
# 2           2  267406515.0    SMR      EUR      ACI_OKR1_UMB  NL0000387058
# 3           3  267406516.0    SMR      EUR      ACI_OKR1_UMB  DE0005419105
# 4           4  267406517.0    SMR      EUR      ACI_OKR1_UMB  IT0003073266
#
#   Transaction Type  Trade Date Settle Date  CUSIP  ...  \
# 0              Buy  11-16-2018  11-20-2018    NaN  ...
# 1             Sell  11-16-2018  11-20-2018    NaN  ...
# 2             Sell  11-16-2018  11-20-2018    NaN  ...
# 3             Sell  11-16-2018  11-20-2018    NaN  ...
# 4             Sell  11-16-2018  11-20-2018    NaN  ...
#
#   Trade Expenses Difference Absolute Accounting OTE Custodian Account  \
# 0                                0.0                              NaN
# ...
