# %%
import pandas as pd

# %%
df_123 = pd.read_csv(r'//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_123.csv')
# Out:
# C:\Users\consultant138\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (2,8,11,22,23,24,26,27,38,40,49,62,63,64,65,66,67,112,142,155,156,162,163,169,182,183,196,205,206,209,210,212,213,214,215,216,218,219,221,222,224,225,226,227,234,235,236,237,238,239,240,241,242,243,244,245,249,250,252,254,255,256,258,260,261,262,263,264,265,266,267,269,270,272,273,275,276,278,279,281,284,291,292,293,294,295,296,297,298,299,300,303,304,306,308,309,310,311,312,314,317,323,326,329,332,338,345,347,351,353,356,357,359,362,365,368,371,374,377,413,416,418,419) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
add_cols = ["ViewData.Side0_UniqueIds", "ViewData.Side1_UniqueIds", 
            "MetaData.0._RecordID", "MetaData.1._RecordID", 
            "ViewData.Task Business Date", "ViewData.Status",
            "ViewData._ID", "ViewData.BreakID"]

# %%
df_123[df_123["ViewData.BreakID"] == NA]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-7f50046123f2> in <module>
# ----> 1 df_123[df_123["ViewData.BreakID"] == NA]
#
# NameError: name 'NA' is not defined

# %%
df_123["ViewData.BreakID"] = df_123["ViewData.BreakID"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6f7b6c31e67a> in <module>
# ----> 1 df_123["ViewData.BreakID"] = df_123["ViewData.BreakID"].astype(int)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
# ...

# %%
df_trail_123 = df_123[add_cols]

# %%
# Note that I am not removing these rows as of now. Just checking for curiosity's sake
df_trail_123[-df_trail_123["ViewData.Status"].isin(["Archive","HST","OC","CT"])]
# Out:
#          ViewData.Side0_UniqueIds ViewData.Side1_UniqueIds  \
# 0                             NaN        21_123703408_CITI
# 24     79_123726192_Advent Geneva                      NaN
# 25     57_123726192_Advent Geneva                      NaN
# 26     25_123726192_Advent Geneva                      NaN
# 27                            NaN        54_123726192_CITI
# ...                           ...                      ...
# 74897  19_123782952_Advent Geneva                      NaN
# 74907                         NaN        68_123841502_CITI
# 74908                         NaN        50_123841502_CITI
# 74909                         NaN        49_123841502_CITI
# 74910                         NaN        67_123841502_CITI
#
#        MetaData.0._RecordID  MetaData.1._RecordID ViewData.Task Business Date  \
# 0                       NaN                   NaN    2020-01-31T00:00:00.000Z
# 24                     79.0                   NaN    2020-01-31T00:00:00.000Z
# ...

# %%
cols_list = ['ViewData.Accounting Net Amount','ViewData._ID', 'ViewData.Age','MetaData.0._RecordID', 'MetaData.1._RecordID',
                    'MetaData.0._ParentID', 'MetaData.1._ParentID',
                               'ViewData.Age WK', 'ViewData.Asset Type Category',
                               'ViewData.B-P Net Amount', 'ViewData.Base Net Amount','ViewData.CUSIP', 
                               'ViewData.Cancel Amount',
                               'ViewData.Cancel Flag',
                               'ViewData.Commission', 'ViewData.Currency', 'ViewData.Custodian',
                               'ViewData.Custodian Account',
                               'ViewData.Description', 'ViewData.ExpiryDate', 'ViewData.Fund',
                               'ViewData.ISIN',
                               'ViewData.Investment Type',
                               #'ViewData.Keys',
                               'ViewData.Mapped Custodian Account',
                               'ViewData.Net Amount Difference',
                               'ViewData.Net Amount Difference Absolute', 'ViewData.OTE Ticker',
                               'ViewData.Price',
                               'ViewData.Prime Broker', 'ViewData.Quantity',
                               'ViewData.SEDOL', 'ViewData.SPM ID', 'ViewData.Settle Date',
                               'ViewData.Strike Price',
                               'ViewData.Ticker', 'ViewData.Trade Date',
                               'ViewData.Transaction Category',
                               'ViewData.Transaction Type', 'ViewData.Underlying Cusip',
                               'ViewData.Underlying ISIN',
                               'ViewData.Underlying Sedol','ViewData.Status','ViewData.BreakID',
                               'ViewData.Side0_UniqueIds','ViewData.Side1_UniqueIds','ViewData.Task Business Date' ]

# %%
df_833 = pd.read_csv(r'//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_833.csv',usecols=cols_list)
# Out:
# C:\Users\consultant138\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,4,56,58,59,60,64,65,66,69,70,73,74,75,76,77,78,79,89,91,94,95,98,99,158,183,195,208,209) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_833 = df_833[~df_833["ViewData.Status"].isin(['Archive','HST', 'OC', 'CT'])]

# %%
df_833['Date']= pd.to_datetime(df_833['ViewData.Task Business Date']).dt.date

# %%
def fun_reset_index(df):
    df = df.reset_index()
    df = df.drop('index',1)
    return df

# %%
audit_trail_columns = ['ViewData._ID','ViewData.Status' ,'ViewData.Age','MetaData.0._RecordID', 'MetaData.1._RecordID',
                    'MetaData.0._ParentID', 'MetaData.1._ParentID','ViewData.Side0_UniqueIds','ViewData.Side1_UniqueIds','Date',
                       'ViewData.Settle Date','ViewData.Trade Date']

# %%
df_833 = fun_reset_index(df_833)

# %% [markdown]
# # Analysing Cancelled transactions

# %%
df_833["ViewData.Status"].value_counts()
# Out:
# OB     1292973
# SDB      49283
# UCB      48009
# SMB      22134
# UMB      17249
# UDB       8834
# SPM       3938
# UMF        803
# CNF        439
# SMR        149
# UMR         93
# UOB         30
# Name: ViewData.Status, dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.1f' % x)
pd.set_option('display.max_columns',None)

# %%
df_833[df_833["ViewData.Status"] == 'CNF'].head()
# Out:
#        MetaData.0._ParentID  MetaData.0._RecordID MetaData.1._ParentID  \
# 121560                  NaN                  41.0                  NaN
# 373979                  NaN                  87.0                  NaN
# 373980                  NaN                  11.0                  NaN
# 373981                  NaN                 193.0                  NaN
# 373982                  NaN                  27.0                  NaN
#
#         MetaData.1._RecordID  ViewData.BreakID ViewData.Status  \
# 121560                   nan      1109379500.0             CNF
# 373979                   nan      1114388093.0             CNF
# 373980                   nan      1114388094.0             CNF
# 373981                   nan      1114388095.0             CNF
# 373982                   nan      1114388096.0             CNF
#
#         ViewData.SPM ID ViewData.Custodian Account ViewData.Currency  \
# 121560              nan              CITIGM_FUT_OG               USD
# ...

# %%
df_833[df_833["ViewData.BreakID"] == 1109379500.0][audit_trail_columns]
# Out:
#                      ViewData._ID ViewData.Status  ViewData.Age  \
# 101955   5e3909d51554581a80c8c5e9             CNF           0.0
# 245235   5e3acc3d1554581a802226f3              OB           2.0
# 348873   5e3bae9c155458044803f0fc              OB           3.0
# 494544   5e3cffdf15545804483f1c2a              OB           4.0
# 575156   5e40c37315545804486d6963              OB           7.0
# 656297   5e4295d5155458119c038d72              OB           8.0
# 739075   5e43bf761554580448d5f604              OB           9.0
# 822689   5e45021d15545814701f31d0              OB          10.0
# 907364   5e463bd7155458044834b860              OB          11.0
# 962825   5e463bd7155458044834b860              OB          11.0
# 968203   5e463bd7155458044834b860              OB          11.0
# 973533   5e463bd7155458044834b860              OB          11.0
# 988713   5e46650b43338220ac60059a             UCB           0.0
# 1021351  5e46650b43338220ac60059a             UCB           0.0
#
# ...

# %%
df_833.columns
# Out:
# Index(['MetaData.0._ParentID', 'MetaData.0._RecordID', 'MetaData.1._ParentID',
#        'MetaData.1._RecordID', 'ViewData.BreakID', 'ViewData.Status',
#        'ViewData.SPM ID', 'ViewData.Custodian Account', 'ViewData.Currency',
#        'ViewData.Transaction Type', 'ViewData.Quantity', 'ViewData.Price',
#        'ViewData.Trade Date', 'ViewData.OTE Ticker', 'ViewData.Ticker',
#        'ViewData.Settle Date', 'ViewData.Fund', 'ViewData.Cancel Amount',
#        'ViewData.CUSIP', 'ViewData.Description', 'ViewData.ISIN',
#        'ViewData.SEDOL', 'ViewData.Underlying Cusip',
#        'ViewData.Underlying ISIN', 'ViewData.Underlying Sedol',
#        'ViewData.Accounting Net Amount', 'ViewData.B-P Net Amount',
#        'ViewData.Net Amount Difference',
#        'ViewData.Net Amount Difference Absolute', 'ViewData.Custodian',
#        'ViewData.Asset Type Category', 'ViewData.Cancel Flag',
#        'ViewData.Investment Type', 'ViewData.Prime Broker',
# ...

# %%
df_833['Date'] = df_833['Date'].astype(str)

# %%
df_833[(df_833['ViewData.Status'] == 'UMB') & (df_833['Date'] > '01-07-2020') ][audit_trail_columns].head(500)
# Out:
#                     ViewData._ID ViewData.Status  ViewData.Age  \
# 61797   5e3788c1155458119ca13f43             UMB          52.0
# 61798   5e3788c1155458119ca13f49             UMB          47.0
# 61799   5e3788c1155458119ca13f4e             UMB          52.0
# 61800   5e3788c1155458119ca13f50             UMB          52.0
# 61801   5e3788c1155458119ca13f56             UMB          52.0
# 61802   5e3788c1155458119ca13f5c             UMB          47.0
# 61803   5e3788c1155458119ca13f40             UMB          54.0
# 61804   5e3788c1155458119ca13f46             UMB          53.0
# 61805   5e3788c1155458119ca13f4a             UMB          53.0
# 61806   5e3788c1155458119ca13f4f             UMB          53.0
# 61807   5e3788c1155458119ca13f54             UMB          68.0
# 61808   5e3788c1155458119ca13f57             UMB          60.0
# 61809   5e3788c1155458119ca13f5d             UMB          53.0
# 61810   5e3788c1155458119ca13f62             UMB          54.0
# ...

# %%
df_833[df_833['ViewData._ID'] == '5e33c91b15545817d4c14c67']
# Out:
# Empty DataFrame
# ...

# %%
df_833[df_833['ViewData._ID'] == '5e33c91b15545817d4c14c60']
# Out:
# Empty DataFrame
# ...

# %%
df_833[df_833['ViewData._ID'] == '5e33c91b15545817d4c14c63']
# Out:
# Empty DataFrame
# ...

# %%
df_833[df_833['ViewData._ID'] == '5e33c91b15545817d4c14c6e']
# Out:
# Empty DataFrame
# ...

# %%
df_833[df_833['ViewData._ID'] == '5e33c91b15545817d4c14c6b']
# Out:
# Empty DataFrame
# ...

# %%
df_833[df_833['ViewData.Side0_UniqueIds'] == '64_833666541_Advent Geneva']
# Out:
#              MetaData.0._ParentID  MetaData.0._RecordID  \
# 61797    5e33c91b15545817d4c14c67                   nan
# 164962   5e3788c1155458119ca13f43                   nan
# 268734   5e390b231554581a80ca281f                   nan
# 373487   5e3acc3d1554581a80228180                   nan
# 512042   5e3bae9c1554580448045161                   nan
# 593211   5e3cffdf15545804483f5f1e                   nan
# 676007   5e40c37315545804486dae21                   nan
# 760485   5e4295d5155458119c03d9bd                   nan
# 844295   5e43bf771554580448d643c7                   nan
# 931195   5e45021d15545814701f8540                   nan
# 1084604  5e463bd815545804483514cd                   nan
# 1157592  5e49fe371554581a808194dd                   nan
# 1246092  5e4b7f71155458147098d7ce                   nan
# 1326473  5e4cd1961554581a80d352df                   nan
# 1481947  5e4e472b1554581e98f7c3ec                   nan
# 1570798  5e4f76161554581a80529170                   nan
# ...

# %%
df_833[df_833['ViewData.Side1_UniqueIds'] == '22_833670335_CITI'].head()
# Out:
#             MetaData.0._ParentID  MetaData.0._RecordID  \
# 61797   5e33c91b15545817d4c14c67                   nan
# 164962  5e3788c1155458119ca13f43                   nan
# 268734  5e390b231554581a80ca281f                   nan
# 373487  5e3acc3d1554581a80228180                   nan
# 512042  5e3bae9c1554580448045161                   nan
#
#             MetaData.1._ParentID  MetaData.1._RecordID  ViewData.BreakID  \
# 61797   5e33c91b15545817d4c14c67                   nan      1038833601.0
# 164962  5e3788c1155458119ca13f43                   nan      1038833601.0
# 268734  5e390b231554581a80ca281f                   nan      1038833601.0
# 373487  5e3acc3d1554581a80228180                   nan      1038833601.0
# 512042  5e3bae9c1554580448045161                   nan      1038833601.0
#
#        ViewData.Status  ViewData.SPM ID ViewData.Custodian Account  \
# 61797              UMB              nan              CITIGM_FUT_OG
# ...

# %%
df_833[df_833['ViewData.BreakID'] == 1038833601.0]
# Out:
#              MetaData.0._ParentID  MetaData.0._RecordID  \
# 61797    5e33c91b15545817d4c14c67                   nan
# 164962   5e3788c1155458119ca13f43                   nan
# 268734   5e390b231554581a80ca281f                   nan
# 373487   5e3acc3d1554581a80228180                   nan
# 512042   5e3bae9c1554580448045161                   nan
# 593211   5e3cffdf15545804483f5f1e                   nan
# 676007   5e40c37315545804486dae21                   nan
# 760485   5e4295d5155458119c03d9bd                   nan
# 844295   5e43bf771554580448d643c7                   nan
# 931195   5e45021d15545814701f8540                   nan
# 1084604  5e463bd815545804483514cd                   nan
# 1157592  5e49fe371554581a808194dd                   nan
# 1246092  5e4b7f71155458147098d7ce                   nan
# 1326473  5e4cd1961554581a80d352df                   nan
# 1481947  5e4e472b1554581e98f7c3ec                   nan
# 1570798  5e4f76161554581a80529170                   nan
# ...

# %%
df_833[df_833['ViewData._ID'] == '5e33c91b15545817d4c14c60'][audit_trail_columns]
# Out:
# Empty DataFrame
# Columns: [ViewData._ID, ViewData.Status, ViewData.Age, MetaData.0._RecordID, MetaData.1._RecordID, MetaData.0._ParentID, MetaData.1._ParentID, ViewData.Side0_UniqueIds, ViewData.Side1_UniqueIds, Date, ViewData.Settle Date, ViewData.Trade Date]
# Index: []

# %%
pd.set_option('display.max_rows',1000)

# %%
df_833[df_833['ViewData._ID'] == '5e3788c1155458119ca140f0'][audit_trail_columns]
# Out:
#                    ViewData._ID ViewData.Status  ViewData.Age  \
# 61819  5e3788c1155458119ca140f0             UMB          54.0
#
#        MetaData.0._RecordID  MetaData.1._RecordID      MetaData.0._ParentID  \
# 61819                   nan                   nan  5e33c91b15545817d4c14d0f
#
#       MetaData.1._ParentID     ViewData.Side0_UniqueIds  \
# 61819                  NaN  413_833663153_Advent Geneva
#
#                                 ViewData.Side1_UniqueIds        Date  \
# 61819  651_833672082_CITI,516_833663153_CITI,652_8336...  2020-01-31
#
#       ViewData.Settle Date ViewData.Trade Date
# 61819           12-11-2019          12-11-2019

# %%
min(df_833['Date'])
# Out:
# datetime.date(2019, 10, 17)

# %%
df_833_status = pd.read_csv("//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_833.csv",usecols=['ViewData.Status'])
# Out:
# C:\Users\consultant138\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (56) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_833_status['ViewData.Status'].value_counts()
# Out:
# OB         1292973
# Archive    1254659
# SDB          49283
# UCB          48009
# SMB          22134
# UMB          17249
# UDB           8834
# SPM           3938
# UMF            803
# CNF            439
# OC             189
# HST            189
# SMR            149
# UMR             93
# UOB             30
# Name: ViewData.Status, dtype: int64

# %%
df_125_status = pd.read_csv("//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_125.csv",usecols=['ViewData.Status'])
# Out:
# C:\Users\consultant138\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (53) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_125_status['ViewData.Status'].value_counts()
# Out:
# OB         966538
# Archive    932974
# SMR        309993
# SMT        113233
# SDB         82195
# HST         40346
# OC          40346
# UCB         29137
# SMB         25436
# UMB         25044
# UDB         14034
# UMR         12051
# SPM          9865
# UMT          4007
# UOB          3492
# CNF           877
# UCC           789
# CMF           367
# UMF            14
# UOC             1
# Name: ViewData.Status, dtype: int64

# %%
df_170_status = pd.read_csv("//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_170.csv",usecols=['ViewData.Status'])

# %%
df_170_status['ViewData.Status'].value_counts()
# Out:
# Archive    928098
# SPM        435767
# OB         274038
# SMB        254637
# UCB         28621
# UDB         14262
# UMB          5324
# UMF          4901
# SMR           809
# CNF           708
# HST           152
# OC            152
# SDB           118
# UMR           115
# UCC             9
# UOB             2
# Name: ViewData.Status, dtype: int64

# %%
df_531_status = pd.read_csv("//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_531.csv",usecols=['ViewData.Status'])
df_531_status['ViewData.Status'].value_counts()
# Out:
# C:\Users\consultant138\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# OB         749020
# Archive    748377
# UMB         56656
# UCB         32843
# UDB          9364
# CNF           480
# UOB           354
# HST            79
# OC             79
# SDB            53
# UCC            53
# UMR             7
# UMF             1
# Name: ViewData.Status, dtype: int64

# %%
df_1200_status = pd.read_csv("//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_1200.csv",usecols=['ViewData.Status'])
df_1200_status['ViewData.Status'].value_counts()
# Out:
# Archive    1099670
# OB         1030487
# SPM         151198
# UCB          48209
# SMB          41463
# UDB           3424
# UMB           1195
# CNF            211
# HST             80
# OC              80
# SDB             55
# UOB             47
# UMR             35
# UCC             33
# SMR             21
# Name: ViewData.Status, dtype: int64

# %%
df_123_status = pd.read_csv("//vitblrdevcons01/Raman  Strategy ML 2.0/All_Data/Weiss/HST_RecData_123.csv",usecols=['ViewData.Status'])
df_123_status['ViewData.Status'].value_counts()
# Out:
# OB         29271
# Archive    28964
# SMR         2265
# SDB          972
# SPM          652
# UMR          332
# OC           265
# HST          265
# SMT          208
# UCB           67
# SMB           54
# UDB           14
# UMT            7
# UCC            5
# CMF            5
# CNF            4
# Name: ViewData.Status, dtype: int64
